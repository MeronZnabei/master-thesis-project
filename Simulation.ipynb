# %% [markdown]
# # Simulation notebook
# This notebook is used for testing the Nile model on the single run *simulation* (not optimization) mode.

# %%
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import pickle

from output_analysis.plotter import HydroModelPlotter
# from plotter.plotting_functions import plot_two_lines_together, line_graph_with_limits
from experimentation.data_generation import generate_input_data

import sys

my_path = sys.path[0]
while my_path[-1] != "/" and my_path[-1] != "\\":
    my_path = my_path[:-1]
sys.path.insert(1, my_path + "Model")

from model.model_nile import ModelNile

# %%
model = ModelNile("None")
model_plotter = HydroModelPlotter(model)

# %%
model = generate_input_data(model, sim_horizon=20)

# %%
pcount = model.overarching_policy.get_total_parameter_count()
np.random.seed(123)
random_policy = np.random.rand(pcount)
zero_policy = np.repeat(0, pcount)

# %%
trial_policies = [random_policy, zero_policy]

for policy in trial_policies:
    model.evaluate(policy)
    model_plotter.plot_received_vs_demand_for_district_raw_condensed("Egypt")
    model_plotter.plot_received_vs_demand_for_district_raw_condensed("Gezira")

    for dam in model.reservoir_names:
        model_plotter.plot_level_with_limits(dam)
        model_plotter.plot_levels_condensed(dam)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\DEV\master-thesis-project\Simulation.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/c%3A/DEV/master-thesis-project/Simulation.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> for policy in trial_policies:
#       <a href='vscode-notebook-cell:/c%3A/DEV/master-thesis-project/Simulation.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     model.evaluate(policy)
# ----> <a href='vscode-notebook-cell:/c%3A/DEV/master-thesis-project/Simulation.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     model_plotter.plot_received_vs_demand_for_district_raw_condensed("Egypt")
#       <a href='vscode-notebook-cell:/c%3A/DEV/master-thesis-project/Simulation.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     model_plotter.plot_received_vs_demand_for_district_raw_condensed("Gezira")
#       <a href='vscode-notebook-cell:/c%3A/DEV/master-thesis-project/Simulation.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     for dam in model.reservoir_names:
#
# File c:\DEV\master-thesis-project\output_analysis\plotter.py:784, in HydroModelPlotter.plot_received_vs_demand_for_district_raw_condensed(self, irr_name)
#     782 def plot_received_vs_demand_for_district_raw_condensed(self, irr_name):
# --> 784     self.plot_condensed_figure(
#     785         vectors=[
#     786             self.hydro_model.irr_districts[irr_name].demand,
#     787             self.hydro_model.irr_districts[irr_name].received_flow_raw,
#     788         ],
#     789         y_name="Flow [m3/sec]",
#     790         labels=[f"{irr_name} Demanded Flow", f"{irr_name} Received Flow"],
#     791         range_exists=[True, True],
#     792         range_alphas=[0.3, 0.3],
#     793         colors=[irr_color[irr_name], color_list[1]],
#     794     )
#
# File c:\DEV\master-thesis-project\output_analysis\plotter.py:664, in HydroModelPlotter.plot_condensed_figure(self, vectors, y_name, title, labels, range_exists, colors, range_alphas, hor_line_positions, hor_line_colors, text_on_horiz, bbox_to_anchor)
#     661 fig, ax = plt.subplots(figsize=self.figsize)
#     663 for i, vector in enumerate(vectors):
# --> 664     vector = np.reshape(vector, (self.n_years, self.n_months))
#     665     avg = np.mean(vector, 0)
#     666     # plotting the average
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File c:\Users\meron\anaconda3\envs\Master_thesis\lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Users\meron\anaconda3\envs\Master_thesis\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 3120 into shape (20,12)

# %% [markdown]
# # Plotting
#
# Below code block will be used to plot some of the actual physical quantities (summary releases across reservoirs, irrigation per catchment, average environmental flows) based on the vectors that were produced by simulation runs:
